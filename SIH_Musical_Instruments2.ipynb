# %% [markdown]
# # importing dataset

# %%
import pandas as pd
df = pd.read_json('C:/Users/Kalyani/Desktop/data_sets/Musical_Instruments.json',lines=True)

# %%
df
# Out:
#              asin   helpful  overall  \
# 0      1384719342    [0, 0]        5
# 1      1384719342  [13, 14]        5
# 2      1384719342    [1, 1]        5
# 3      1384719342    [0, 0]        5
# 4      1384719342    [0, 0]        5
# 5      B00004Y2UT    [0, 0]        5
# 6      B00004Y2UT    [0, 0]        5
# 7      B00004Y2UT    [0, 0]        3
# 8      B00004Y2UT    [0, 0]        5
# 9      B00004Y2UT    [0, 0]        5
# 10     B00004Y2UT    [6, 6]        5
# 11     B00005ML71    [0, 0]        4
# 12     B00005ML71    [0, 0]        3
# 13     B00005ML71    [0, 0]        5
# 14     B00005ML71    [0, 0]        5
# 15     B00005ML71    [0, 0]        2
# 16     B000068NSX    [0, 0]        4
# 17     B000068NSX    [0, 0]        5
# 18     B000068NSX    [3, 3]        5
# 19     B000068NSX    [0, 0]        5
# 20     B000068NSX    [0, 0]        4
# 21     B000068NSX    [0, 0]        5
# 22     B000068NSX    [0, 0]        4
# 23     B000068NTU    [0, 0]        5
# 24     B000068NTU    [0, 0]        5
# 25     B000068NTU    [0, 0]        4
# 26     B000068NTU    [0, 0]        5
# 27     B000068NTU    [0, 0]        5
# 28     B000068NVI    [1, 1]        4
# 29     B000068NVI    [0, 0]        5
# ...           ...       ...      ...
# 10231  B00IZCSW3M    [1, 1]        5
# 10232  B00IZCSW3M    [0, 0]        5
# 10233  B00IZCSW3M    [7, 7]        5
# 10234  B00IZCSW3M    [1, 1]        5
# 10235  B00IZCSW3M    [1, 2]        5
# 10236  B00IZCSW3M    [0, 0]        5
# 10237  B00IZCSW3M   [8, 10]        3
# 10238  B00IZCSW3M    [0, 0]        5
# 10239  B00IZCSW3M    [2, 2]        5
# 10240  B00J4TBMVO    [0, 0]        5
# 10241  B00J4TBMVO    [0, 0]        5
# 10242  B00J4TBMVO    [0, 0]        5
# 10243  B00J4TBMVO    [0, 0]        5
# 10244  B00J4TBMVO    [0, 0]        5
# 10245  B00J4TBMVO    [0, 0]        4
# 10246  B00J4TBMVO    [0, 0]        5
# 10247  B00J4TBMVO    [2, 2]        2
# 10248  B00JBIVXGC    [0, 0]        5
# 10249  B00JBIVXGC    [0, 0]        5
# 10250  B00JBIVXGC    [0, 0]        5
# 10251  B00JBIVXGC    [0, 0]        5
# 10252  B00JBIVXGC    [0, 0]        5
# 10253  B00JBIVXGC    [0, 0]        4
# 10254  B00JBIVXGC    [0, 0]        5
# 10255  B00JBIVXGC    [0, 0]        3
# 10256  B00JBIVXGC    [0, 0]        5
# 10257  B00JBIVXGC    [0, 0]        5
# 10258  B00JBIVXGC    [0, 0]        4
# 10259  B00JBIVXGC    [0, 0]        4
# 10260  B00JBIVXGC    [0, 0]        4
#
#                                               reviewText   reviewTime  \
# 0      Not much to write about here, but it does exac...  02 28, 2014
# 1      The product does exactly as it should and is q...  03 16, 2013
# 2      The primary job of this device is to block the...  08 28, 2013
# 3      Nice windscreen protects my MXL mic and preven...  02 14, 2014
# 4      This pop filter is great. It looks and perform...  02 21, 2014
# 5      So good that I bought another one.  Love the h...  12 21, 2012
# 6      I have used monster cables for years, and with...  01 19, 2014
# 7      I now use this cable to run from the output of...  11 16, 2012
# 8      Perfect for my Epiphone Sheraton II.  Monster ...   07 6, 2008
# 9      Monster makes the best cables and a lifetime w...   01 8, 2014
# 10     Monster makes a wide array of cables, includin...  04 19, 2012
# 11     I got it to have it if I needed it. I have fou...  04 22, 2014
# 12     If you are not use to using a large sustaining...  11 17, 2013
# 13     I love it, I used this for my Yamaha ypt-230 a...  06 16, 2013
# 14     I bought this to use in my home studio to cont...  12 31, 2012
# 15     I bought this to use with my keyboard. I wasn'...  08 17, 2013
# 16     This Fender cable is the perfect length for me...  08 13, 2013
# 17     wanted it just on looks alone...It is a nice l...   07 9, 2013
# 18     I've been using these cables for more than 4 m...  03 18, 2013
# 19     Fender cords look great and work just as well....   08 7, 2013
# 20     This is a cool looking cheap cable which works...  03 16, 2012
# 21     The Fender 18 Feet California Clear Instrument...  01 29, 2014
# 22     Very good cable. Well made and it looks great ...   12 8, 2012
# 23     Got this cable to run a rockband keyboard cont...   07 5, 2012
# 24     When I was searching for MIDI cables for my AR...  10 31, 2013
# 25     Cant go wrong. Great quality on a budget price...   07 3, 2013
# 26     The ends of the midi cable look and feel like ...  01 25, 2012
# 27     Just trying to find a midi to midi was a task,...  10 15, 2013
# 28     The Hosa XLR cables are affordable and very he...  07 11, 2012
# 29     I bought these to go from my board to the amp....  02 19, 2014
# ...                                                  ...          ...
# 10231  For a long time, I never thought much about gu...   05 1, 2014
# 10232  My father is a full-time gigging musician prim...  06 14, 2014
# 10233  D'Addario has always been one of the best stri...  05 22, 2014
# 10234  I usually use Gibson Vintage Nickle Strings on...  05 11, 2014
# 10235  Excellent tone, and I'm a bit surprised by tha...  05 31, 2014
# 10236  I've been stringing my guitars with D'Addario ...  05 25, 2014
# 10237  Don't get me wrong, the improvement over the o...  04 28, 2014
# 10238  These have a nice bright sound and are easy on...  06 18, 2014
# 10239  D'Addario's NYXL1046 Nickel Plated Electric Gu...  06 17, 2014
# 10240  Just put these on my Martin DCX1E and they sou...  07 11, 2014
# 10241  I ordered this for my husband, the musician. H...  06 25, 2014
# 10242  I had used Elixer strings for several years on...  07 10, 2014
# 10243  I can't speak on the claim for a longer string...  07 12, 2014
# 10244  Great product with nice feel and tone. I'm onl...  06 26, 2014
# 10245  I have reviewed these strings before, and fran...   07 1, 2014
# 10246  I had the opportunity to try a set of Elixir N...  07 19, 2014
# 10247  I was looking forward to trying these, as I've...  06 24, 2014
# 10248  I put these strings on my Guild acoustic elect...  07 11, 2014
# 10249  I ordered this for my husband, the musician.  ...  06 22, 2014
# 10250  I had used Elixer strings for several years on...  07 10, 2014
# 10251  True to phosphor bronze these strings have a m...   07 1, 2014
# 10252  I've used Elixirs for about five years now. Th...  06 30, 2014
# 10253  I'm a D'Addario man myself, but hey free is fr...  07 21, 2014
# 10254  I really like these strings.  While they are n...   07 4, 2014
# 10255  I have lots of friends who play these strings....  06 25, 2014
# 10256            Great, just as expected.  Thank to all.  07 20, 2014
# 10257  I've been thinking about trying the Nanoweb st...   07 2, 2014
# 10258  I have tried coated strings in the past ( incl...  07 22, 2014
# 10259  Well, MADE by Elixir and DEVELOPED with Taylor...   07 1, 2014
# 10260  These strings are really quite good, but I wou...  07 16, 2014
#
#            reviewerID                                      reviewerName  \
# 0      A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1      A14VAT5EAX3D9S                                              Jake
# 2      A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3      A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4       A94QU4C90B1AX                                     SEAN MASLANKA
# 5      A2A039TZMZHH9Y                               Bill Lewey "blewey"
# 6      A1UPZM995ZAH90                                             Brian
# 7       AJNFQI3YR6XJ5                                 Fender Guy "Rick"
# 8      A3M1PLEYNDEYO8                                   G. Thomas "Tom"
# 9       AMNTZU1YQN1TH                                       Kurt Robair
# 10     A2NYK9KWFMJV4Y                       Mike Tarrani "Jazz Drummer"
# 11     A35QFQI0M46LWO                                     Christopher C
# 12     A2NIT6BKW11XJQ                                               Jai
# 13     A1C0O09LOLVI39                                           Michael
# 14     A17SLR18TUMULM                                       Straydogger
# 15     A2PD27UKAD3Q00              Wilhelmina Zeitgeist "coolartsybabe"
# 16      AKSFZ4G1AXYFC                                      C.E. "Frank"
# 17      A67OJZLHBBUQ9                  Charles F. Marks "charlie marks"
# 18     A2EZWZ8MBEDOLN                                            Charlo
# 19     A1CL807EOUPVP1                                           GunHawk
# 20     A1GMWTGXW682GB                                          MetalFan
# 21     A2G12DY50U700V                                       Ricky Shows
# 22      A3E0CF25A7LD2                                            WBowie
# 23     A2W3CLAYZLDPTV                         Amazon Customer "=Chris="
# 24     A398X9POBHK69N                                   Ann Vande Zande
# 25      AXWB93VKVML6K                                    Michael Hassey
# 26     A2FZ4Z0UFA1OR8                                               Pat
# 27      AXP9CF1UTFRSU                                              tada
# 28     A2CCGGDGZ694CT                                          b carney
# 29     A27DR1VO079F1V                                         Dan Edman
# ...               ...                                               ...
# 10231  A31RULW0KNYJ5H                                                LA
# 10232  A3KZEGBTPH6MMF                                  Lucy Cat "Mandy"
# 10233   AWCJ12KBO5VII                                  Michael L. Knapp
# 10234  A29B4PAIOL7HYG                          N. Caruso "gibsonjunkie"
# 10235  A27L5L6I7OSV5B                                      Otto Correct
# 10236   AOMEH9W6LHC4S                                          Personne
# 10237  A3VDSGNIS92OVZ                               P. Hamm "p-squared"
# 10238  A27H0T39U3FZB5                        P. MSakamoto "boy clothes"
# 10239  A2PD27UKAD3Q00              Wilhelmina Zeitgeist "coolartsybabe"
# 10240  A146H4KN4LFR60                                         angelfood
# 10241  A3A7Y3TSPPZU9T                                       coffeebrain
# 10242  A30J7WQV0ZNRXG                         D. Reinstein "marindavid"
# 10243  A3M1PLEYNDEYO8                                   G. Thomas "Tom"
# 10244  A3KX8SVSUCSHKU                                              john
# 10245  A1TSKKBNV38E8Y                       K. Harriger "K.R. Harriger"
# 10246  A29B4PAIOL7HYG                          N. Caruso "gibsonjunkie"
# 10247  A3VDSGNIS92OVZ                               P. Hamm "p-squared"
# 10256                                         Five Stars      1405814400
# 10257  Long life, and for some players, a good econom...      1404259200
# 10258                                   Good for coated.      1405987200
# 10259                                        Taylor Made      1404172800
# 10260  These strings are really quite good, but I wou...      1405468800
#
# [10261 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# asin               0
# helpful            0
# overall            0
# reviewText         0
# reviewTime         0
# reviewerID         0
# reviewerName      27
# summary            0
# unixReviewTime     0
# dtype: int64

# %%
df = df.drop(labels = ['asin'],axis=1)
df = df.drop(labels = ['helpful'],axis=1)
df = df.drop(labels = ['unixReviewTime'],axis=1)
df = df.drop(labels = ['reviewerName'],axis=1)
df = df.drop(labels = ['reviewerID'],axis=1)
df = df.drop(labels = ['reviewTime'],axis=1)
df = df.drop(labels = ['summary'],axis=1)

# %%
df
# Out:
#        overall                                         reviewText
# 0            5  Not much to write about here, but it does exac...
# 1            5  The product does exactly as it should and is q...
# 2            5  The primary job of this device is to block the...
# 3            5  Nice windscreen protects my MXL mic and preven...
# 4            5  This pop filter is great. It looks and perform...
# 5            5  So good that I bought another one.  Love the h...
# 6            5  I have used monster cables for years, and with...
# 7            3  I now use this cable to run from the output of...
# 8            5  Perfect for my Epiphone Sheraton II.  Monster ...
# 9            5  Monster makes the best cables and a lifetime w...
# 10           5  Monster makes a wide array of cables, includin...
# 11           4  I got it to have it if I needed it. I have fou...
# 12           3  If you are not use to using a large sustaining...
# 13           5  I love it, I used this for my Yamaha ypt-230 a...
# 14           5  I bought this to use in my home studio to cont...
# 15           2  I bought this to use with my keyboard. I wasn'...
# 16           4  This Fender cable is the perfect length for me...
# 17           5  wanted it just on looks alone...It is a nice l...
# 18           5  I've been using these cables for more than 4 m...
# 19           5  Fender cords look great and work just as well....
# 20           4  This is a cool looking cheap cable which works...
# 21           5  The Fender 18 Feet California Clear Instrument...
# 22           4  Very good cable. Well made and it looks great ...
# 23           5  Got this cable to run a rockband keyboard cont...
# 24           5  When I was searching for MIDI cables for my AR...
# 25           4  Cant go wrong. Great quality on a budget price...
# 26           5  The ends of the midi cable look and feel like ...
# 27           5  Just trying to find a midi to midi was a task,...
# 28           4  The Hosa XLR cables are affordable and very he...
# 29           5  I bought these to go from my board to the amp....
# ...        ...                                                ...
# 10231        5  For a long time, I never thought much about gu...
# 10232        5  My father is a full-time gigging musician prim...
# 10233        5  D'Addario has always been one of the best stri...
# 10234        5  I usually use Gibson Vintage Nickle Strings on...
# 10235        5  Excellent tone, and I'm a bit surprised by tha...
# 10236        5  I've been stringing my guitars with D'Addario ...
# 10237        3  Don't get me wrong, the improvement over the o...
# 10238        5  These have a nice bright sound and are easy on...
# 10239        5  D'Addario's NYXL1046 Nickel Plated Electric Gu...
# 10240        5  Just put these on my Martin DCX1E and they sou...
# 10241        5  I ordered this for my husband, the musician. H...
# 10242        5  I had used Elixer strings for several years on...
# 10243        5  I can't speak on the claim for a longer string...
# 10244        5  Great product with nice feel and tone. I'm onl...
# 10245        4  I have reviewed these strings before, and fran...
# 10246        5  I had the opportunity to try a set of Elixir N...
# 10247        2  I was looking forward to trying these, as I've...
# 10248        5  I put these strings on my Guild acoustic elect...
# 10249        5  I ordered this for my husband, the musician.  ...
# 10250        5  I had used Elixer strings for several years on...
# 10251        5  True to phosphor bronze these strings have a m...
# 10252        5  I've used Elixirs for about five years now. Th...
# 10253        4  I'm a D'Addario man myself, but hey free is fr...
# 10254        5  I really like these strings.  While they are n...
# 10255        3  I have lots of friends who play these strings....
# 10256        5            Great, just as expected.  Thank to all.
# 10257        5  I've been thinking about trying the Nanoweb st...
# 10258        4  I have tried coated strings in the past ( incl...
# 10259        4  Well, MADE by Elixir and DEVELOPED with Taylor...
# 10260        4  These strings are really quite good, but I wou...
#
# [10261 rows x 2 columns]

# %%
df.sort_values('overall').head()
# Out:
#       overall                                         reviewText
# 8704        1  A great idea, but pure crap in terms of functi...
# 6222        1  I had some issues with my 18-watt all tube amp...
# 5206        1  They say 2-4 months, I've never come close to ...
# 6873        1  I thought it was my jack for a while, then I n...
# 6869        1  I have a real problem with these patch cables....

# %%
y = df['overall']
x = df['reviewText']

# %% [markdown]
# # splitting data

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.head()
# Out:
# 9078    This is very nice holder which holds my guitar...
# 2354    Nothing too crazy here. It holds your picks an...
# 7787    This comes COMPLETE with bridge, saddles and f...
# 4023    A great add on to my student model for acousti...
# 773     They work as well as any Dunlop pick; they don...
# Name: reviewText, dtype: object

# %%
y_train.head()
# Out:
# 9078    3
# 2354    5
# 7787    5
# 4023    5
# 773     5
# Name: overall, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(x_train)
vectors = vectorizer.transform(x_train)
print(vectorizer.get_feature_names())
# Out:
# ['00', '000', '001', '004', '0045', '007', '008', '009', '00e', '00ibanez', '00mm', '01', '010', '010s', '011', '0115', '011s', '012', '012dlx', '012s', '013', '0135', '013s', '016', '017', '01s', '02', '020', '022uf', '025', '026', '03', '032', '034', '036', '04', '042', '046i', '04mm', '05', '053', '054', '055', '06', '07', '073', '07etc', '07mkii', '08', '0818', '085', '08nov2010', '09', '099', '0it', '0mm', '0s', '10', '100', '1000', '1000000x', '1000ma', '1000x', '100digitech', '100joyo', '100l', '100ma', '100maoutput', '100mavisual', '100usd', '100w', '100x', '101', '103', '105', '108', '10a125', '10bd', '10cm', '10db', '10foot', '10footers', '10ft', '10k', '10mm', '10p', '10s', '10th', '10ths', '10w', '10watts', '10x', '11', '110', '1100', '110v', '111', '112', '1122', '114', '114si', '115', '118', '119', '11mm', '11s', '11u', '12', '120', '1200', '1202', '1202fx', '120s', '123', '125', '1274', '128', '128sample', '12at7', '12ax7', '12ax7lps', '12axt', '12ay7', '12db', '12ft', '12h', '12i', '12mm', '12o', '12still', '12th', '12u', '12v', '12vac', '12vdc', '13', '130', '1300', '1303', '135', '1350ma', '1357264576', '1358133926', '1361565768', '13been', '13i', '14', '140', '1400', '140s', '149', '14lbs', '14mm', '14mmwhich', '14th', '15', '150', '1500', '150ibanez', '150maoutput', '154', '15db', '15foot', '15khz', '15lb', '15lbs', '15s', '15th', '
fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bd7f486de255> in <module>()
# ----> 1 text_clf.fit(x_train,y_train)
#
# NameError: name 'text_clf' is not defined

# %%
from sklearn.svm import LinearSVC
clf=LinearSVC()

from sklearn.pipeline import Pipeline
text_clf = Pipeline([('tfidf',TfidfVectorizer()), ('clf',LinearSVC())])

# %%
text_clf.fit(x_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#  ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
predictions = text_clf.predict(x_test)
from sklearn import metrics

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
metrics.accuracy_score(y_test,predictions)
# Out:
# 0.6734573368762917

# %%
df['overall'].replace(([1,2,3,4,5]),['neg','neg','neutral','pos','pos'],inplace=True)
df
# Out:
#        overall                                         reviewText
# 0          pos  Not much to write about here, but it does exac...
# 1          pos  The product does exactly as it should and is q...
# 2          pos  The primary job of this device is to block the...
# 3          pos  Nice windscreen protects my MXL mic and preven...
# 4          pos  This pop filter is great. It looks and perform...
# 5          pos  So good that I bought another one.  Love the h...
# 6          pos  I have used monster cables for years, and with...
# 7      neutral  I now use this cable to run from the output of...
# 8          pos  Perfect for my Epiphone Sheraton II.  Monster ...
# 9          pos  Monster makes the best cables and a lifetime w...
# 10         pos  Monster makes a wide array of cables, includin...
# 11         pos  I got it to have it if I needed it. I have fou...
# 12     neutral  If you are not use to using a large sustaining...
# 13         pos  I love it, I used this for my Yamaha ypt-230 a...
# 14         pos  I bought this to use in my home studio to cont...
# 15         neg  I bought this to use with my keyboard. I wasn'...
# 16         pos  This Fender cable is the perfect length for me...
# 17         pos  wanted it just on looks alone...It is a nice l...
# 18         pos  I've been using these cables for more than 4 m...
# 19         pos  Fender cords look great and work just as well....
# 20         pos  This is a cool looking cheap cable which works...
# 21         pos  The Fender 18 Feet California Clear Instrument...
# 22         pos  Very good cable. Well made and it looks great ...
# 23         pos  Got this cable to run a rockband keyboard cont...
# 24         pos  When I was searching for MIDI cables for my AR...
# 25         pos  Cant go wrong. Great quality on a budget price...
# 26         pos  The ends of the midi cable look and feel like ...
# 27         pos  Just trying to find a midi to midi was a task,...
# 28         pos  The Hosa XLR cables are affordable and very he...
# 29         pos  I bought these to go from my board to the amp....
# ...        ...                                                ...
# 10231      pos  For a long time, I never thought much about gu...
# 10232      pos  My father is a full-time gigging musician prim...
# 10233      pos  D'Addario has always been one of the best stri...
# 10234      pos  I usually use Gibson Vintage Nickle Strings on...
# 10235      pos  Excellent tone, and I'm a bit surprised by tha...
# 10236      pos  I've been stringing my guitars with D'Addario ...
# 10237  neutral  Don't get me wrong, the improvement over the o...
# 10238      pos  These have a nice bright sound and are easy on...
# 10239      pos  D'Addario's NYXL1046 Nickel Plated Electric Gu...
# 10240      pos  Just put these on my Martin DCX1E and they sou...
# 10241      pos  I ordered this for my husband, the musician. H...
# 10242      pos  I had used Elixer strings for several years on...
# 10243      pos  I can't speak on the claim for a longer string...
# 10244      pos  Great product with nice feel and tone. I'm onl...
# 10245      pos  I have reviewed these strings before, and fran...
# 10246      pos  I had the opportunity to try a set of Elixir N...
# 10247      neg  I was looking forward to trying these, as I've...
# 10248      pos  I put these strings on my Guild acoustic elect...
# 10249      pos  I ordered this for my husband, the musician.  ...
# 10250      pos  I had used Elixer strings for several years on...
# 10251      pos  True to phosphor bronze these strings have a m...
# 10252      pos  I've used Elixirs for about five years now. Th...
# 10253      pos  I'm a D'Addario man myself, but hey free is fr...
# 10254      pos  I really like these strings.  While they are n...
# 10255  neutral  I have lots of friends who play these strings....
# 10256      pos            Great, just as expected.  Thank to all.
# 10257      pos  I've been thinking about trying the Nanoweb st...
# 10258      pos  I have tried coated strings in the past ( incl...
# 10259      pos  Well, MADE by Elixir and DEVELOPED with Taylor...
# 10260      pos  These strings are really quite good, but I wou...
#
# [10261 rows x 2 columns]

# %%
df['reviewText'][0]
# Out:
# "Not much to write about here, but it does exactly what it's supposed to. filters out the pop sounds. now my recordings are much more crisp. it is one of the lowest prices pop filters on amazon so might as well buy it, they honestly work the same despite their pricing,"

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.head()
# Out:
# 9078    This is very nice holder which holds my guitar...
# 2354    Nothing too crazy here. It holds your picks an...
# 7787    This comes COMPLETE with bridge, saddles and f...
# 4023    A great add on to my student model for acousti...
# 773     They work as well as any Dunlop pick; they don...
# Name: reviewText, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(x_train)
vectors = vectorizer.transform(x_train)
print(vectorizer.get_feature_names())
# Out:
# ['00', '000', '001', '004', '0045', '007', '008', '009', '00e', '00ibanez', '00mm', '01', '010', '010s', '011', '0115', '011s', '012', '012dlx', '012s', '013', '0135', '013s', '016', '017', '01s', '02', '020', '022uf', '025', '026', '03', '032', '034', '036', '04', '042', '046i', '04mm', '05', '053', '054', '055', '06', '07', '073', '07etc', '07mkii', '08', '0818', '085', '08nov2010', '09', '099', '0it', '0mm', '0s', '10', '100', '1000', '1000000x', '1000ma', '1000x', '100digitech', '100joyo', '100l', '100ma', '100maoutput', '100mavisual', '100usd', '100w', '100x', '101', '103', '105', '108', '10a125', '10bd', '10cm', '10db', '10foot', '10footers', '10ft', '10k', '10mm', '10p', '10s', '10th', '10ths', '10w', '10watts', '10x', '11', '110', '1100', '110v', '111', '112', '1122', '114', '114si', '115', '118', '119', '11mm', '11s', '11u', '12', '120', '1200', '1202', '1202fx', '120s', '123', '125', '1274', '128', '128sample', '12at7', '12ax7', '12ax7lps', '12axt', '12ay7', '12db', '12ft', '12h', '12i', '12mm', '12o', '12still', '12th', '12u', '12v', '12vac', '12vdc', '13', '130', '1300', '1303', '135', '1350ma', '1357264576', '1358133926', '1361565768', '13been', '13i', '14', '140', '1400', '140s', '149', '14lbs', '14mm', '14mmwhich', '14th', '15', '150', '1500', '150ibanez', '150maoutput', '154', '15db', '15foot', '15khz', '15lb', '15lbs', '15s', '15th', '15w', '15watt', '16', '160', '162', '165', '169', '16bits', '16ny', '16ohms', '16s', '16th', '16u', '17', '170', '1700', '1700ma', '175', '179', '18', '180', '1800', '1800xm', '18ams2', '18v', '18vd', '19', '190lbs', '192', '192k', '192khz', '1931', '1940s', '1948', '1950', '1950s', '1957', '1959', '1960', '1960a', '1960b', '1960s', '1962', '1963', '1966', '1967', '1968', '1969', '1970', '1970s', '1973', '1976', '1978', '1979', '1980', '1981', '1982', '1984', '1985', '1989', '199', '1990', '1990s', '1991', '1993', '1994', '1995', '1996', '1a', '1db', '1e', '1frd1', '1k', '1khz', '1mm', '1s', '1spot', '1st', '1u', '1w', '1x', '1x12', '1x12out', '1x8', '20', '200', '2000', '2000hz', '2000s', '2000xm', '2003', '2003a', '2004', '2005', '2006', '2007', '2008', '2009', '200ma', '200w', '201', '2010', '2011', '2011my', '2012', '2012i', '2012the', '2013', '2013i', '2013so', '2013still', '2014', '201s', '202', '2020', '2032', '2035', '2036', '205k', '206', '207', '208', '2080', '20db', '20foot', '20hours', '20hz', '20mm', '20s', '20w', '20xl', '21', '210', '2100', '2101', '212', '212r', '212rline', '214ce', '21ft', '21st', '22', '220', '2203kk', '220sce', '220v', '222', '223k', '225', '2290', '22db', '22mm', '23', '230', '235', '24', '240', '2406', '240v', '243a', '245', '2488', '249', '24bit', '24th', '24yrs', '25', '250', '255', '2552', '256mb', '25db', '25ft', '25i', '25r', '25well', '26', '26mm', '27', '28', '280', '282', '289k', '28mm', '28strand', '29', '290', '299', '29s', '2amps', '2bn', '2db', '2e', '2ea', '2gb', '2ghz', '2i2', '2inch', '2k', '2mins', '2mm', '2nd', '2snark', '2stars', '2track', '2x', '2x10', '2x10kustom', '2x12', '2yr', '30', '300', '3000', '3001', '300ma', '300majoyo', '300maoutput', '300nx', '301', '302usb', '3031a', '305', '30bucks', '30gn', '30or', '30pk', '30s', '30w', '30years', '31', '3124', '3150', '315k', '32', '320', '322', '325', '3250l', '32gb', '32gbs', '32ms', '32yrs', '33', '333', '335', '339', '34', '340', '340vdc', '346', '35', '350', '350hz', '351', '351s', '355', '356', '35db', '35pk', '35yrs', '36', '360', '365', '365vdc', '366', '375', '38', '38mm', '38mmdespite', '39', '390', '391', '399', '3d', '3db0', '3ft', '3fx', '3gs', '3khz', '3mm', '3o', '3rd', '3rds', '3realtimesoft', '3s', '3the', '3v', '3which', '3x', '3x3', '3yo', '40', '400', '4000', '4003', '4033', '4037', '4050', '406', '4080', '40lbs', '40plus', '40w', '41', '410', '410ce', '412', '414ce', '42', '420', '4200', '423r60', '427p3', '43', '430', '432', '438hz', '439', '44', '440', '440hz', '440s', '45', '450', '4558', '456', '45deg', '45lb', '45mn', '46', '469', '46mm', '47', '48' ...

# %%
print(vectors.shape)
# Out:
# (6874, 16998)

# %%
text_clf.fit(x_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#  ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
from sklearn.svm import LinearSVC
clf=LinearSVC()

from sklearn.pipeline import Pipeline
text_clf = Pipeline([('tfidf',TfidfVectorizer()), ('clf',LinearSVC())])

# %%
text_clf.fit(x_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#  ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
predictions = text_clf.predict(x_test)
from sklearn import metrics

# %%
predictions = text_clf.predict(x_test)
from sklearn import metrics

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
metrics.accuracy_score(y_test,predictions)
# Out:
# 0.8845586064363744
